# %% [markdown]
# import random
# import pyspark
# num_samples = 100000000
#
# sc.stop()
# sc = pyspark.SparkContext(appName="Pi")
# num_samples = 100000000
#
# def inside(p):
#   x, y = random.random(), random.random()
#   return x*x + y*y < 1
#
# count = sc.parallelize(range(0, num_samples)).filter(inside).count()
#
# pi = 4 * count / num_samples
# print(pi)
#
# sc.stop()

# %%
# %run -i '../spark-historian-consumer.py'
# Out:
# <class 'dict'>
# DATE 2019-09-03T00:28:26, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:28:31, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:28:42, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:01, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:32, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:37, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:43, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:47, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:53, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:29:57, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:30:02, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:08, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:30:17, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:38, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:30:53, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:58, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:31:08, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:31:38, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:31:48, VALUE 17
# <class 'dict'>
# DATE 2019-09-03T00:31:53, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:32:03, VALUE 17
# <class 'dict'>
# DATE 2019-09-03T00:32:14, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:32:24, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:32:29, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:09, VALUE 18
# <class 'dict'>
# DATE 2019-09-03T00:33:15, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:19, VALUE 18
# <class 'dict'>
# DATE 2019-09-03T00:33:25, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:33:30, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:35, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:33:40, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:00:28, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:00:38, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:00:54, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:00:58, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:13, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:18, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:43, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:49, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:54, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:59, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:03:09, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:03:15, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:03:35, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:03:41, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:03:45, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:10, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:15, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:21, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:25, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:30, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:40, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:04:46, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:51, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:05:01, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:05:06, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:05:26, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:05:31, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:05:52, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:06:02, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:11, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:27, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:36, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:52, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:57, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:03, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:12, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:18, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:37, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:03, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:08:13, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:28, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:08:34, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:38, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:08, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:14, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:19, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:23, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:29, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:09:34, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:49, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:54, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:10:34, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:10:44, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:10:54, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:11:30, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:11:40, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:12:30, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:12:36, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:13:37, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:13:41, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:14:17, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:14:21, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:14:36, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:14:42, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:14:57, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:15:02, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:15:12, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:15:17, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:15:27, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:15:38, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:15:48, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:15:52, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:15:58, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:16:23, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:16:28, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:17:19, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:17:23, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:17:34, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:17:39, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:17:54, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:17:59, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:18:05, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:18:14, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:18:19, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:18:39, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:18:45, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:19:00, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:19:05, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:19:10, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:19:15, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:19:46, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:19:50, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:20:16, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:20:20, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:20:31, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:20:41, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:20:56, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:21:01, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:21:07, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:21:22, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:21:26, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:21:31, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:21:37, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:21:41, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:21:47, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:21:52, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:22:02, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:22:12, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:22:42, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:22:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:22:57, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:23:02, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:23:07, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:23:13, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:23:37, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:23:43, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:23:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:23:53, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:23:58, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:24:03, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:24:13, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:24:19, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:24:33, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:24:54, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:24:59, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:25:44, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:25:49, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:25:54, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:26:00, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:26:04, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:26:09, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:26:19, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:26:25, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:26:40, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:26:50, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:26:55, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:27:00, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:27:16, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:27:20, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:27:35, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:27:41, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:27:51, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:27:56, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:28:26, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:28:31, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:28:42, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:01, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:32, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:37, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:43, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:29:47, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:29:53, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:29:57, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:30:02, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:08, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:30:17, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:38, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:30:53, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:30:58, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:31:08, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:31:38, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:31:48, VALUE 17
# <class 'dict'>
# DATE 2019-09-03T00:31:53, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:32:03, VALUE 17
# <class 'dict'>
# DATE 2019-09-03T00:32:14, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:32:24, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:32:29, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:09, VALUE 18
# <class 'dict'>
# DATE 2019-09-03T00:33:15, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:19, VALUE 18
# <class 'dict'>
# DATE 2019-09-03T00:33:25, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:33:30, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:35, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:33:40, VALUE 16
# <class 'dict'>
# DATE 2019-09-03T00:33:44, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:34:00, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:34:20, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:34:25, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:34:55, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:35:01, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:35:10, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:35:16, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:35:26, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:35:41, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:35:46, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:35:56, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:36:02, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:36:21, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:36:27, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:36:42, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:36:47, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:36:57, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:37:02, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:37:22, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:37:33, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:37:42, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:37:48, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:37:52, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:38:03, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:38:08, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:38:18, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:38:33, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:38:38, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:38:43, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:38:48, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:38:53, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:39:14, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:39:19, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:39:38, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:39:44, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:40:15, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:40:19, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:40:34, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:40:39, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:40:45, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:40:49, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:41:15, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:41:19, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:41:30, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:41:35, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:41:45, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:41:55, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:42:01, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:42:05, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:42:16, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:42:31, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:42:35, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:42:46, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:43:06, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:43:16, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:43:21, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:43:41, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:43:46, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:43:52, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:43:56, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:44:17, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:44:22, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:44:41, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:44:52, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:44:57, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:45:02, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:45:12, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:45:17, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:45:23, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:45:32, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:45:42, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:46:18, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:46:23, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:46:28, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:46:38, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:46:49, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:46:59, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:47:08, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:00:28, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:00:38, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:00:54, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:00:58, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:13, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:18, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:43, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:49, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:01:54, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:01:59, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:03:09, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:03:15, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:03:35, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:03:41, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:03:45, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:10, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:15, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:21, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:25, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:04:30, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:40, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:04:46, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:04:51, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:05:01, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:05:06, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:05:26, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:05:31, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:05:52, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:06:02, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:11, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:27, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:36, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:06:52, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:06:57, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:03, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:07, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:12, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:18, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:07:37, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:07:48, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:03, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:08:13, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:28, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:08:34, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:08:38, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:08, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:14, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:19, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:23, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:29, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:09:34, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:09:49, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:09:54, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:10:34, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:10:44, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:10:54, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:11:30, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:11:40, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:12:30, VALUE 12
# <class 'dict'>
# DATE 2019-09-03T00:12:36, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:13:37, VALUE 15
# <class 'dict'>
# DATE 2019-09-03T00:13:41, VALUE 13
# <class 'dict'>
# DATE 2019-09-03T00:14:17, VALUE 14
# <class 'dict'>
# DATE 2019-09-03T00:14:21, VALUE 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/DataAnalysisFramework-ref/python/TimeSeries/historian-consumer.py in <module>
#      26 if __name__=="__main__":
#      27     tags=["CRY-CENTRALE-SOLAIRE-CRY-act-prod-pow","CRY-TGBT-NORMAL-CRY-act-cons-pow","LAU-PHOTOVOLTAIQUE-LAU-app-prod-pow"]
# ---> 28     main(tags[1])
#
# ~/DataAnalysisFramework-ref/python/TimeSeries/historian-consumer.py in main(tag)
#      15     consumer = KafkaConsumer("historian-topic-"+tag, bootstrap_servers='localhost:9092', group_id="historian-monitor")
#      16
# ---> 17     for message in consumer:
#      18         recv_data = json.loads(message.value.decode())
#      19         print(type(recv_data))
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# ~/local/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %%
# %run -i '../kafka-producer.py'
# Out:
# row :
#  01/01/2019 09:15:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0    01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_a...
# Name: 0, dtype: object
# ---end row---
#
# count :  0
#
# Value :  01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# message : 0:01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# 1582539062.7142618 Produced records[0] : 0:01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# row :
#  01/01/2019 09:15:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0    01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_a...
# Name: 1, dtype: object
# ---end row---
#
# count :  1
#
# Value :  01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
#
# message : 1:01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
#
# 1582539063.7208745 Produced records[1] : 1:01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# row :
#  01/01/2019 09:15:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0    01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_a...
# Name: 2, dtype: object
# ---end row---
#
# count :  2
#
# Value :  01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# message : 2:01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# 1582539064.7269213 Produced records[2] : 2:01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# row :
#  01/01/2019 09:15:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0    01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_a...
# Name: 3, dtype: object
# ---end row---
#
# count :  3
#
# Value :  01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
#
# message : 3:01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
#
# 1582539065.7329044 Produced records[3] : 3:01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# row :
#  01/01/2019 09:15:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0    01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_a...
# Name: 4, dtype: object
# ---end row---
#
# count :  4
#
# Value :  01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# message : 4:01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
#
# 1582539066.7379344 Produced records[4] : 4:01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/DataAnalysisFramework-ref/python/TimeSeries/kafka-producer.py in <module>
#      55     data_folder='/work/weiy/DataAnalysisFramework-ref/data/TimeSeries'
#      56     test='dataHistorian-Cryolite-20190101-OneDay.csv'
# ---> 57     main(data_folder,test)
#
# ~/DataAnalysisFramework-ref/python/TimeSeries/kafka-producer.py in main(folder, file)
#      49             producer.send("mytopic",msg.encode('utf8'))
#      50             print("{} Produced records[{}] : {}".format(time.time(), index,msg))
# ---> 51             time.sleep(1)
#      52
#      53
#
# KeyboardInterrupt:

# %%
# %run -i '../kafka-consumer.py'
# Out:
# RECEIVED MSG 276:01/01/2019 11:41:12;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;4.000000000;100.0
# RECEIVED MSG 277:01/01/2019 11:41:27;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;3.000000000;100.0
# RECEIVED MSG 278:01/01/2019 11:41:32;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;4.000000000;100.0
# RECEIVED MSG 0:01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 1:01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 2:01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 3:01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 4:01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 5:01/01/2019 09:16:13;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 6:01/01/2019 09:16:23;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 7:01/01/2019 09:16:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 8:01/01/2019 09:16:59;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 9:01/01/2019 09:17:03;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 10:01/01/2019 09:17:09;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 11:01/01/2019 09:17:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 12:01/01/2019 09:17:24;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 13:01/01/2019 09:17:29;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 14:01/01/2019 09:17:34;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 15:01/01/2019 09:17:39;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 16:01/01/2019 09:17:44;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 17:01/01/2019 09:17:55;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 18:01/01/2019 09:17:59;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 19:01/01/2019 09:18:10;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 20:01/01/2019 09:18:14;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 21:01/01/2019 09:18:29;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 22:01/01/2019 09:18:35;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 23:01/01/2019 09:20:16;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 24:01/01/2019 09:20:21;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 25:01/01/2019 09:20:56;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 26:01/01/2019 09:21:01;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 27:01/01/2019 09:21:31;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 28:01/01/2019 09:21:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 29:01/01/2019 09:22:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 30:01/01/2019 09:22:57;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 31:01/01/2019 09:23:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 32:01/01/2019 09:24:03;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 33:01/01/2019 09:24:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 34:01/01/2019 09:24:24;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 35:01/01/2019 09:24:28;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 36:01/01/2019 09:24:33;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 37:01/01/2019 09:25:19;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 38:01/01/2019 09:25:29;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 39:01/01/2019 09:25:39;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 40:01/01/2019 09:25:44;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 0:01/01/2019 09:15:18;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 1:01/01/2019 09:15:37;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 2:01/01/2019 09:15:43;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# RECEIVED MSG 3:01/01/2019 09:15:53;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;1.000000000;100.0
# RECEIVED MSG 4:01/01/2019 09:15:58;CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow;0.000000000;100.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/DataAnalysisFramework-ref/python/TimeSeries/kafka-consumer.py in <module>
#      20
#      21 if __name__=="__main__":
# ---> 22     main()
#
# ~/DataAnalysisFramework-ref/python/TimeSeries/kafka-consumer.py in main()
#      15     consumer = KafkaConsumer("mytopic", bootstrap_servers='localhost:9092', group_id="historian-monitor")
#      16
# ---> 17     for message in consumer:
#      18         msg = message.value.decode()
#      19         print('RECEIVED MSG',msg)
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# ~/local/anaconda3/lib/python3.7/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# ~/local/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %%
# %run -i '../spark-historian-consumer.py'
# Out:
# -----begin-----
# [('spark.driver.memory', '2G'), ('spark.logConf', 'True'), ('spark.master', 'local[*]'), ('spark.submit.pyFiles', ''), ('spark.executor.cores', '1'), ('spark.submit.deployMode', 'client'), ('spark.app.name', 'UnitTest'), ('spark.executor.memory', '1G'), ('spark.driver.maxResultSize', '10G'), ('spark.ui.showConsoleProgress', 'true'), ('spark.cores.max', '32')]
# ---------------------------
# attempting
# SparkContext created
# <SparkContext master=local[*] appName=PySparkShell>
# SPARK CONTEXT INFO  :
#       VERSION       : 3.0.0-preview2
#       DRIVER MEMORY : None
# check parsed

# %%
print(sc)
sc.stop()

# %%
print(type(sc))

# %%
if 'sc' not in locals():
    print("heihei")
