# %%
# %run ../TimeSeriesTools/warp10_test.py --function "test_insert"
# Out:
# Results:
#  154633411200000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# 154633411800000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[0.0, 100.0]'
# 154633413700000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# 154633414300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[0.0, 100.0]'
# 154633415300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# 154633415800000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[0.0, 100.0]'
# 154633417300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# 154633418300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[0.0, 100.0]'
# 154633421300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# 154633421900000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[0.0, 100.0]'
# 154633422300000// smartGrid{Tag=CRY.CENTRALE_SOLAIRE.CRY_act_prod_pow} '[1.0, 100.0]'
# ...

# %%
# building, device, log

# %%
# %run ../TimeSeriesTools/warp10_test.py --function "find_data"
# Out:
# opening fetch_test.mc2
#  warp10 server answer 200
# ...

# %%
# creer list(dict) -> df[data] (json loads)

# %%
# %run ../TimeSeriesTools/warp10_test.py --function "delete_data"
# Out:
# http://127.0.0.1:9090/api/v0/delete?deleteall&selector=smartGrid{}
